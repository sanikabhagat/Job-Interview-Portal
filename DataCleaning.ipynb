# %%
import numpy as np
import pandas as pd

# %%
test=pd.read_csv("C:\\Users\\Sanika\\Desktop\\Final Project\\convertcsv.csv")

# %%
test.head()
# Out:
#      digit    first      last                  email       alpha
# 0  1888713    Maria   Griffin           uwo@sita.edu  DjpJsfBVrj
# 1  1888714  Harriet    Little           hicil@pa.edu  YsbZjyvDWE
# 2  1888715     Rosa    Norton           kano@sog.edu  zYEmVlMouJ
# 3  1888716    Lewis    Vargas     tuile@wufusdoc.edu  bWRwbgoDhD
# 4  1888717  Harriet  Anderson  ahelutuz@mofzoaji.edu  kOatdeJBrX

# %%
test["Email"]=test["first"].str[0]+"."+test["last"]+"@neu.edu"

# %%
test.head()
# Out:
#      digit    first      last                  email       alpha  \
# 0  1888713    Maria   Griffin           uwo@sita.edu  DjpJsfBVrj
# 1  1888714  Harriet    Little           hicil@pa.edu  YsbZjyvDWE
# 2  1888715     Rosa    Norton           kano@sog.edu  zYEmVlMouJ
# 3  1888716    Lewis    Vargas     tuile@wufusdoc.edu  bWRwbgoDhD
# 4  1888717  Harriet  Anderson  ahelutuz@mofzoaji.edu  kOatdeJBrX
#
#                 Email
# 0   m.griffin@neu.edu
# 1    h.little@neu.edu
# 2    r.norton@neu.edu
# 3    l.vargas@neu.edu
# 4  h.anderson@neu.edu

# %%
test["Email"]=test['Email'].apply(lambda x: lower_scale(x))

# %%
test.head()
# Out:
#      digit    first      last                  email       alpha  \
# 0  1888713    Maria   Griffin           uwo@sita.edu  DjpJsfBVrj
# 1  1888714  Harriet    Little           hicil@pa.edu  YsbZjyvDWE
# 2  1888715     Rosa    Norton           kano@sog.edu  zYEmVlMouJ
# 3  1888716    Lewis    Vargas     tuile@wufusdoc.edu  bWRwbgoDhD
# 4  1888717  Harriet  Anderson  ahelutuz@mofzoaji.edu  kOatdeJBrX
#
#                 Email
# 0   m.griffin@neu.edu
# 1    h.little@neu.edu
# 2    r.norton@neu.edu
# 3    l.vargas@neu.edu
# 4  h.anderson@neu.edu

# %%
test.to_csv("C:\\Users\\Sanika\\Desktop\\Final Project\\convertcsv.csv")
